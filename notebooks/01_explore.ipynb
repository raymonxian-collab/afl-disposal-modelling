# %% [markdown]
# <a href="https://colab.research.google.com/github/raymonxian-collab/afl-disposal-modelling/blob/main/notebooks/01_explore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print("Setup working")
# Out:
# Setup working
